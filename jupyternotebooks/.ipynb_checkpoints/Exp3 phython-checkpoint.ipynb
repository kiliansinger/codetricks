# %% [raw]
# # Exp3 Python tutorial
# https://github.com/jupyterlab/jupyterlab/issues/14752
# https://etpwww.etp.kit.edu/~quast/Skripte/diving_into_ROOT.pdf
#
# see also https://lucydot.github.io/python_novice/
#
# shortcuts: https://stackoverflow.com/questions/38195536/jupyter-shortcut-not-working
#
# https://medium.com/@girish1729/how-to-install-javascript-and-c-into-jupyter-notebook-9c8f281a9b1a#:~:text=We%20have%20seen%20how%20Jupyter,as%20aiding%20in%20collaborative%20development.
#
# pip3 install jupyter-c-kernel
#
# install_c_kernel --userr
#
# https://www.youtube.com/watch?v=9XWCm9iV-wk
#
# https://github.com/jupyter-xeus/xeus-cling
#
# create a python environment from bundled python
#
# jlab env create --name=test-env --source=bundle
#
# and activate it to use pip3 and ...
#
# jlab env activate test-env
#
# https://jupyterlab.readthedocs.io/en/stable/user/commands.html
#
# https://www.youtube.com/watch?v=aOz-Xj_znrs
#
# https://github.com/conda-forge/miniforge
#
# https://github.com/jupyter-xeus/xeus
#
#
# after setting path to c:\rootxxxx\bin
#
#  in console you get it by clicking on right folder and then + and then select console
#
#   pip install notebook
#
#  do root --notebook
#
#  then it opens in browser and there type import ROOT select python kernel there you can now follow https://root.cern.ch/notebooks/HowTos/HowTo_ROOT-Notebooks.html
#
# does not work yet is:
#
# https://docs.posit.co/ide/server-pro/user/2023.03.1/jupyter-lab/guide/jupyter-kernel-management.html
#
#  jupyter kernelspec install C:\root_v6.30.04\etc\notebook\kernels\root\
#
#  https://support.esri.com/en-us/knowledge-base/how-to-install-a-new-kernel-in-jupyter-notebook-using-a-000019210
#
# https://discourse.jupyter.org/t/root-c-kernel-does-not-work-in-jupyterhub-but-work-well-in-jupyter-lab-solved/5882
#
#   jupyter notebook --generate-config
#
# https://stackoverflow.com/questions/34976803/sys-path-different-in-jupyter-and-python-how-to-import-own-modules-in-jupyter
#
# https://jupyter-client.readthedocs.io/en/stable/kernels.html#kernel-specs
#
# https://stackoverflow.com/questions/34976803/sys-path-different-in-jupyter-and-python-how-to-import-own-modules-in-jupyter
#
# pip install metakernel
#
# {
# "language": "c++",
# "display_name": "ROOT C++",
# "argv": [
#     "C:\\Users\\admin\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\python.exe",
#     "-m",
#     "JupyROOT.kernel.rootkernel",
#     "-f",
#     "{connection_file}"
# ],
#     "env": {
#         "CD": "c:\\root_v6.30.04\\bin",
#         "PYTHONPATH": "c:\\root_v6.30.04\\bin"
#     }
# }
#
# install python kernel:
#
# ipython kernel install --prefix C:\Users\admin\Documents\jupy t
#
# edit:
#
#
# {
# "language": "python",
# "display_name": "ROOT python",
# "argv": [
#     "C:\\Users\\admin\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\python.exe",
#     "-m",
#     "ipykernel_launcher",
#     "- "{connection_file}"
# ],
#     "\\bin",
#         "PYTHONPATH": "c:\\root_v6.30.04\\bin"
#     }
# }
#
#
#
#
#
# ```

# %%
import ROOT
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import ROOT
#
# ModuleNotFoundError: No module named 'ROOT'

# %% [markdown]
# 1.  Get funding.
# 2.  Do work.
#     *   Design experiment.
#     *   Collect data.
#     *   Analyze.
# 3.  Write up. $\alpha$
# 4.  Publish.

# %%
x = 6 * 7 + 12
print(x)

# %%
 pip install jupyter-c-kernel

# %%
install_c_kernel --user

# %%
#include <stdio.h>
#include <stdlib.h>
#include <unistd.h>
int main(){
    
    printf("elle");
}

# %%
a=[1,2,3]
b=a
c=a[:]
b[0]="X"
c[0]="Y"

print(a)
print(b)
print(c)

# %%
def fibo(n):
    if n==0:
        return 0
    else:
        return fibo(n-1)+n

print(fibo(50))

# %%
for x in range(1,10):
    print(x)

# %%
1==1

# %%
import math
print("pi is",math.pi)

# %%
math?

# %%
help(math)

# %%
from math import cos, pi
print(cos(pi))

# %%
import math as m
print(m.pi)

# %%
pi

# %%
import numpy as np

# %%
10*11/2

# %%
30*31/2

# %%
f=open("transmittance.csv", encoding='utf-8-sig')
header=f.readline()
f.close()
lll=np.loadtxt("transmittance.csv",delimiter=",",skiprows=1)

# %%
print(lll)

# %%
print(lll.type)
lll

# %%
help np.loadtxt

# %%
import csv    
import numpy as np

with n('tpetransmittance.csv', newline='') as f_input:
    data = np.genfromtxt((','.join(row) for row in csv.reader(f_input)), delimiter=',')

print(data)

# %%
a=np.zeros(10)

# %%
a

# %%
np.loadtxt?

# %%
import os

# %%
print(os.getcwd())

# %%
np.sin(2)

# %% [markdown]
# [test](test.ipynb)

# %% [markdown]
# [markdown](test.md)

# %%
print(type(lll))

# %%
print(lll.dtype)

# %%
numpy=np
times = numpy.linspace(0,10,50)

# %%
times

# %%
for index, value in enumerate([10,20,30]):
    print("index is: ", index)
    print("value is: ", value)

# %%
a=enumerate([10,20,30])

# %%
print(a)

# %%
import numpy

g = 9.81 # acceleration due to gravity in m/s^2
v_0 = numpy.array([[-10,0,10,20]]).transpose() # starting velocities in m/s
times = numpy.array([numpy.linspace(0,100,5000)]) # times between 0 and 10s
velocity_array = v_0 + g*times

# %%
v_0 = numpy.array([[-10,0,10,20]])

# %%
v_0

# %%
pip install jupyter metakernel

# %%
import ROOT

# %% [markdown]
# https://jupyter-client.readthedocs.io/en/latest/kernels.html
# https://github.com/root-project/root/tree/master/bindings/jupyroot

# %%
TCanvas c;

# %%
pip install ROOT

# %%
import ROOT
